# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# ### Trip dates

# %%
trip_start = '2018-01-10'
trip_end = '2018-01-25'

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine,reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# Creating inspector object
inspector = inspect(engine)

# %%
# Inspecting measurement table using inspector
measurement_cols = inspector.get_columns('measurement')
for col in measurement_cols:
    print(col['name'], col['type'])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Inspecting station table using inspector
station_cols = inspector.get_columns('station')
for col in station_cols:
    print(col['name'], col['type'])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
stations= session.query(Station.station).all()
stations_list = list(np.ravel(stations))
stations_list
# Out:
# ['USC00519397',
#  'USC00513117',
#  'USC00514830',
#  'USC00517948',
#  'USC00518838',
#  'USC00519523',
#  'USC00519281',
#  'USC00511918',
#  'USC00516128']

# %% [markdown]
# # Exploratory Climate Analysis

# %% [markdown]
# ## Precipitation Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results
# Query the date of the last data point
last_point_date = session.query(Measurement.date).order_by(Measurement.date.desc()).first()

# Convert last_point_date into a datetime object
lp_date_obj = dt.datetime.strptime(last_point_date[0],'%Y-%m-%d')

# Calculate the date 1 year ago from the last data point in the database
one_year_ago = lp_date_obj - dt.timedelta(days=366)
one_year_ago

# Perform a query to retrieve the data and precipitation scores
last_year_data = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date>=one_year_ago).all()

# Save the query results as a Pandas DataFrame and set the index to the date column
measurements_df = pd.DataFrame(last_year_data, columns = ('date', 'precipitation'))

measurements_df.set_index('date',inplace=True)
measurements_df

# Sort the dataframe by date
measurements_df = measurements_df.sort_values(by='date', ascending=True)
measurements_df
# Use Pandas Plotting with Matplotlib to plot the data
ax = measurements_df.plot(figsize=(12,8))
ax.set_xlabel('Date')
ax.set_ylabel('Inches')
plt.tight_layout()
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
measurements_df.describe()
# Out:
#        precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %% [markdown]
# ## Station Analysis

# %%
# Design a query to show how many stations are available in this dataset?
session.query(Station.station).count()
# Out:
# 9

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
session.query(Measurement.station, func.count(Measurement.tobs)).group_by(Measurement.station).order_by(func.count(Measurement.tobs).desc()).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
most_active_station = session.query(Measurement.station, func.count(Measurement.tobs)).group_by(Measurement.station).\
order_by(func.count(Measurement.tobs).desc()).first()[0]
most_active_station
# Out:
# 'USC00519281'

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?

lowest_temp = session.query(func.min(Measurement.tobs)).filter(Measurement.station==most_active_station).first()[0]
print(f'The lowest temp of the most active station is lowest_temp = {lowest_temp}')

highest_temp = session.query(func.max(Measurement.tobs)).filter(Measurement.station==most_active_station).first()[0]
print(f'The highest temp of the most active station is lowest_temp = {highest_temp}')

average_temp = session.query(func.avg(Measurement.tobs)).filter(Measurement.station==most_active_station).first()[0]
print(f'The average temp of the most active station is lowest_temp = {round(average_temp,1)}')
# Out:
# The lowest temp of the most active station is lowest_temp = 54.0
# The highest temp of the most active station is lowest_temp = 85.0
# The average temp of the most active station is lowest_temp = 71.7

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station
most_active_lastyear_temp = session.query(Measurement.tobs).filter((Measurement.station==most_active_station),\
                                                                   (Measurement.date>=one_year_ago)).all()
temp_list = [temp[0] for temp in most_active_lastyear_temp]
temp_list
#plot the results as a histogram
plt.figure(figsize=(12,8))
plt.hist(temp_list, bins=12)
plt.legend(('tobs',),loc='best')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bonus Challenge Assignment

# %% [markdown]
# ## Temperature Analysis I

# %%
# Query average temperature in June for all years
june_days = ['06-0'+str(d) for d in range(1,10)]
june_days.extend(['06-'+str(d) for d in range(10,31)])
june_avg = []
for day in june_days:
    june_avg.append(session.query(func.avg(Measurement.tobs)).filter(func.strftime("%m-%d", Measurement.date) == day).all())
    
june_avg = np.ravel(june_avg)
june_avg
# Out:
# array([74.61403509, 74.4       , 74.03448276, 73.81818182, 74.85454545,
#        75.1754386 , 75.07142857, 75.5862069 , 75.15254237, 75.14285714,
#        76.01960784, 75.66666667, 75.66666667, 75.62711864, 75.40350877,
#        75.4137931 , 74.59322034, 74.60344828, 75.44067797, 73.96491228,
#        74.75862069, 75.15789474, 74.54385965, 74.96428571, 74.10344828,
#        74.21428571, 75.01785714, 74.88679245, 74.91525424, 75.59615385])

# %%
# Query average temperature in December for all years with excluding December 31st to get equal length arrays
december_days = ['06-0'+str(d) for d in range(1,10)]
december_days.extend(['06-'+str(d) for d in range(10,31)])
december_avg = []
for day in december_days:
    december_avg.append(session.query(func.avg(Measurement.tobs)).filter(func.strftime("%m-%d", Measurement.date) == day).all())

december_avg = np.ravel(december_avg)
december_avg
# Out:
# array([74.61403509, 74.4       , 74.03448276, 73.81818182, 74.85454545,
#        75.1754386 , 75.07142857, 75.5862069 , 75.15254237, 75.14285714,
#        76.01960784, 75.66666667, 75.66666667, 75.62711864, 75.40350877,
#        75.4137931 , 74.59322034, 74.60344828, 75.44067797, 73.96491228,
#        74.75862069, 75.15789474, 74.54385965, 74.96428571, 74.10344828,
#        74.21428571, 75.01785714, 74.88679245, 74.91525424, 75.59615385])

# %%
# Do a paired t-test for both results as they are measured with the same sensors but in different times
import scipy.stats as stats
stats.ttest_rel(december_avg, june_avg, nan_policy='omit')
# Out:
# Ttest_relResult(statistic=nan, pvalue=nan)

# %% [markdown]
# #### Couldn't solve the problem of ttest returning nan values

# %% [markdown]
# ## Temperature Analysis II

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
py_trip_start = '2017-01-10'
py_trip_end = '2017-01-25'
trip_temps = np.ravel(calc_temps(py_trip_start, py_trip_end))
tmin = trip_temps[0]
tavg = trip_temps[1]
tmax = trip_temps[2]
tavg
# Out:
# 70.8080808080808

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
plt.title("Trip Avg Temp")
plt.ylabel("Temp(F)")
x = ["Trip average temp"]
y = tavg
yerr = tmax-tmin
plt.ylim(top=100)
plt.bar(x,y,yerr=yerr,color='coral',alpha=0.5)
plt.show()

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
sel = [func.sum(Measurement.prcp), Station.station, Station.name, Station.latitude, Station.longitude, Station.elevation]

prcp_trip = session.query(*sel).filter(Station.station==Measurement.station).filter(Measurement.date >= py_trip_start).\
filter(Measurement.date <= py_trip_end).group_by(Station.id).order_by(func.sum(Measurement.prcp).desc()).all()

prcp_df = pd.DataFrame(prcp_trip, columns=('Total rainfall per station', 'Station id', 'Station name', 'Latitude', 'Longitude', 'Elevation'))

prcp_df
# Out:
#    Total rainfall per station   Station id  \
# 0                        6.22  USC00516128
# 1                        1.08  USC00519281
# 2                        0.40  USC00513117
# 3                        0.23  USC00519397
# 4                        0.23  USC00519523
# 5                        0.02  USC00514830
# 6                        0.00  USC00517948
#
#                              Station name  Latitude  Longitude  Elevation
# 0            MANOA LYON ARBO 785.2, HI US  21.33310 -157.80250      152.4
# 1                     WAIHEE 837.5, HI US  21.45167 -157.84889       32.9
# 2                    KANEOHE 838.1, HI US  21.42340 -157.80150       14.6
# 3                    WAIKIKI 717.2, HI US  21.27160 -157.81680        3.0
# 4      WAIMANALO EXPERIMENTAL FARM, HI US  21.33556 -157.71139       19.5
# 5  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.52130 -157.83740        7.0
# 6                       PEARL CITY, HI US  21.39340 -157.97510       11.9

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`
# Set the start and end date of the trip
trip_start = '2018-01-10'
trip_end = '2018-01-25'

# Use the start and end date to create a range of dates
trip_start_date = dt.datetime.strptime(trip_start,'%Y-%m-%d')
trip_end_date = dt.datetime.strptime(trip_end,'%Y-%m-%d')
trip_duration = (trip_end_date-trip_start_date).days

trip_dates = [trip_start_date]
date = trip_start_date
for i in range(trip_duration):
    date += dt.timedelta(days=1)
    trip_dates.append(date)
# Stip off the year and save a list of %m-%d strings
month_day_strings = [date.strftime("%m-%d") for date in trip_dates]

# Loop through the list of %m-%d strings and calculate the normals for each date
normals = []
for date in month_day_strings:
    normals.append(np.ravel(daily_normals(date)))
normals
# Out:
# [array([62.        , 69.74137931, 77.        ]),
#  array([57.        , 67.31034483, 78.        ]),
#  array([57.        , 67.40740741, 81.        ]),
#  array([57.        , 67.25454545, 77.        ]),
#  array([58.        , 69.52631579, 77.        ]),
#  array([56.        , 69.31372549, 78.        ]),
#  array([54.        , 68.62962963, 80.        ]),
#  array([61.        , 69.07407407, 76.        ]),
#  array([57.        , 68.63157895, 77.        ]),
#  array([60.        , 68.26315789, 78.        ]),
#  array([61.        , 68.86666667, 78.        ]),
#  array([61.        , 70.14545455, 76.        ]),
#  array([60.        , 69.26415094, 76.        ]),
#  array([57.        , 69.50909091, 79.        ]),
#  array([58.        , 68.76271186, 78.        ]),
#  array([61.        , 67.94915254, 75.        ])]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index
normal_min = [n[0] for n in normals]
normal_avg = [n[1] for n in normals]
normal_max = [n[2] for n in normals]
normals_df = pd.DataFrame({'Date':trip_dates ,'Normal minimum':normal_min, 'Normal average':normal_avg, 'Normal maximum':normal_max})
normals_df.set_index('Date',inplace=True)

normals_df
# Out:
#             Normal minimum  Normal average  Normal maximum
# Date
# 2018-01-10            62.0       69.741379            77.0
# 2018-01-11            57.0       67.310345            78.0
# 2018-01-12            57.0       67.407407            81.0
# 2018-01-13            57.0       67.254545            77.0
# 2018-01-14            58.0       69.526316            77.0
# 2018-01-15            56.0       69.313725            78.0
# 2018-01-16            54.0       68.629630            80.0
# 2018-01-17            61.0       69.074074            76.0
# 2018-01-18            57.0       68.631579            77.0
# 2018-01-19            60.0       68.263158            78.0
# 2018-01-20            61.0       68.866667            78.0
# 2018-01-21            61.0       70.145455            76.0
# 2018-01-22            60.0       69.264151            76.0
# 2018-01-23            57.0       69.509091            79.0
# 2018-01-24            58.0       68.762712            78.0
# ...

# %%
# Plot the daily normals as an area plot with `stacked=False`
ax = normals_df.plot.area(stacked=False, figsize=(12,8))
ax.set(ylabel='Temperature')
plt.show()
